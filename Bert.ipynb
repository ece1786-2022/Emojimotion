# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10036/1408506528.py in <module>
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google'

# %%
# !git clone https://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@github.com/ece1786-2022/Emojimotion.git
# Out:
# 'git' 不是内部或外部命令，也不是可运行的程序
# 或批处理文件。

# %%
# !git config --global user.email "a953025027@gmail.com"
# !git config --global user.name "carolgao66"

# %%
# !pip install transformers
# !pip install datasets
# !pip install jupyter_http_over_ws

# %%
jupyter serverextension enable -- py jupyter_http_over_ws

# %%
import pandas as pd
import re
from nltk import flatten
import numpy as np
import pandas as pd
import numpy as np
import torch
import torchtext
from torchtext import data
import torch.optim as optim
import tensorflow as tf
import argparse
import os
import torch.nn.functional as F
import torch.nn as nn
import logging
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from datasets import Dataset
# import gensim.downloader as api
torch.cuda.empty_cache()
np.random.seed(43)
torch.manual_seed(43)

# %%
test = pd.read_csv('/content/Emojimotion/datasets_tweets/test.csv')
train=pd.read_csv('/content/Emojimotion/datasets_tweets/train.csv')
valid=pd.read_csv('/content/Emojimotion/datasets_tweets/valid.csv')

# %%
train.head()

# %%
from transformers import BertTokenizer, BertForSequenceClassification

# %%
model_name='bert-base-uncased'
max_length=512
tokenizer=BertTokenizer.from_pretrained(model_name,do_lower_case=True)

# %%
train=Dataset.from_dict(train)
test=Dataset.from_dict(test)
valid=Dataset.from_dict(valid)

# %%
a=train['tweets'][0]
a

# %%
print(tokenizer(a)['input_ids'])

# %%
tokenizer("merry xmas")['input_ids']

# %%
print(tokenizer.tokenize(a))

# %%
def tokenize_function(examples):
    return tokenizer(examples["tweets"], padding="max_length", truncation=True)
tokenized_train = train.map(tokenize_function, batched=True)
tokenized_valid = valid.map(tokenize_function, batched=True) 
tokenized_test = test.map(tokenize_function, batched=True)

# %%
tokenized_train

# %%
from transformers import TrainingArguments,Trainer,DataCollatorWithPadding
model = BertForSequenceClassification.from_pretrained(model_name,num_labels=60)

# %%
data_collator=DataCollatorWithPadding(tokenizer=tokenizer)
training_args = TrainingArguments('nlp-getting-started',
          num_train_epochs=5,
          per_device_train_batch_size=5, 
          per_device_eval_batch_size=64,
          learning_rate=1e-5,
          weight_decay=0.01,
          load_best_model_at_end=True,
          save_strategy='epoch',
          evaluation_strategy="epoch")   # batch size for evaluation)                           )

# %%
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return metric.compute(predictions=predictions, references=labels)

# %%
trainer=Trainer(model=model,
    args=training_args,
    train_dataset=tokenized_train,
    eval_dataset=tokenized_valid,
    data_collator=data_collator,
    tokenizer=tokenizer)

# %%
train.train()
