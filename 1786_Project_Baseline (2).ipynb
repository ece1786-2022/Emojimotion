# %%
import pandas as pd
import re
from nltk import flatten
import numpy as np
import pandas as pd
import numpy as np
import torch
import torchtext
from torchtext import data
import torch.optim as optim
import tensorflow as tf
import argparse
import os
import torch.nn.functional as F
import torch.nn as nn
import logging
import matplotlib.pyplot as plt
np.random.seed(43)
torch.manual_seed(43)

# %% [markdown]
# # Data pre-processing work related to baseline model

# %%
data = pd.read_csv('cleaned_tweets.csv')
emoji_data = pd.read_csv('emoji.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222863 entries, 0 to 222862
# Data columns (total 5 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   index   222863 non-null  int64
#  1   id      222863 non-null  int64
#  2   time    222863 non-null  object
#  3   tweets  222863 non-null  object
#  4   emoji   222863 non-null  object
# dtypes: int64(2), object(3)
# memory usage: 8.5+ MB

# %%
emoji_data.head()
# Out:
#    Unnamed: 0 symbol                    Name      Score
# 0          46      👏     CLAPPING HANDS SIGN  196063427
# 1          31      💖         SPARKLING HEART  268002254
# 2          49      🌹                    ROSE  188924541
# 3          33      ✅  WHITE HEAVY CHECK MARK  246454960
# 4           8      😔            PENSIVE FACE  610729615

# %% [markdown]
# **Formatting the input data to a desired format**

# %%
tweets_posts=[]
target_number=[]
target_emoji=[]
num_emoji=2000
#take 250 examples for now
for e in emoji_data['symbol']:
  tweets_posts.append(data[data.emoji==e]['tweets'][:num_emoji].tolist()) #find the first 250 (subject to change) tweets of emoji e
  target_number.append([emoji_data[emoji_data['symbol']==e].index.values]*num_emoji) #append the index of emoji e 250 times (subject to change) to a list
  target_emoji.append([e]*num_emoji)

#they are nested list so need to flatten them
target_number=flatten(target_number)
target_number=[i[0] for i in target_number]
target_emoji=flatten(target_emoji)
tweets_posts=flatten(tweets_posts)

#create a dictionary
data2 = {'tweets':tweets_posts,
        'emojis_num':target_number,
         'emoji':target_emoji}

# %% [markdown]
# **Train Validation Split**

# %%
from sklearn.model_selection import train_test_split

# %%
#convert dictionary to a dataframe
tweets_dataset = pd.DataFrame(data2)
tweets_dataset.head()
# Out:
#                                               tweets  emojis_num emoji
# 0  love to see it  the numbers they both pull is ...           0     👏
# 1     a story book scene.. congrats to both of you!            0     👏
# 2                  four arms  more like... "for us"            0     👏
# 3  here here. an amazing team of reps delivering ...           0     👏
# 4                    they should do that to all cex.           0     👏

# %%
train,test0=train_test_split(tweets_dataset,test_size=0.36,random_state=1)
valid,test=train_test_split(test0,test_size=20/36,random_state=1)
train=train.reset_index(drop=True)
valid=valid.reset_index(drop=True)
test=test.reset_index(drop=True)
train.head()
# Out:
#                                               tweets  emojis_num emoji
# 0                             they're so adorable!!           58     🍃
# 1      19:33:57,travel far enough you meet yourself.          32     💓
# 2  i interviewed michael saylor and asked him abo...          37     👇
# 3  since mid-90’s around 1995 or so (i was born i...          53     🌺
# 4  congrats on winning the biggest ga ever reply ...          22    ✔️

# %% [markdown]
# **Convert Y_data to one-hot format as required by baseline model**

# %%
a=train["tweets"][0]
a
# Out:
# "they're so adorable!! "

# %%
b=train["emojis_num"][0:3]
c=torch.tensor(b)
d=F.one_hot(c,num_classes=60)
d.reshape(-1,60)
d.shape
# Out:
# torch.Size([3, 60])

# %% [markdown]
# # Baseline Model

# %%
# TextDataset is Described in Section 3.3 of Assignment 2

class TextDataset(torch.utils.data.Dataset):
    def __init__(self,vocab,df):
        # data_path = "data"
        # df = pd.read_csv(os.path.join(data_path, f"{split}.tsv"), sep="\t")
       
        # X: torch.tensor (maxlen, batch_size), padded indices
        # Y: torch.tensor of len N
        X, Y = [], []
        V = len(vocab.vectors)
        for i, row in df.iterrows():
            
            # L = row["tweets"].split()
            L=re.split('[ ,.!?:$&*/\|<>^+=]',row["tweets"])
            # L = L.split()
            # no_extraspace = [" ".join(i.split()) for i in no_newlinechar]
            L=[j for j in L if j]
            # print("original",row["tweets"],"L",L)
            X.append(torch.tensor([vocab.stoi.get(w, V-1) for w in L]))  # Use the last word in the vocab as the "out-of-vocabulary" token
            temp=row["emojis_num"]
            temp=torch.tensor(temp)
            temp=F.one_hot(temp,num_classes=60)
            # print("Y",temp)
            Y.append(temp)
            # Y.append(row["emojis_num"])
        self.X = X 
        self.Y = Y
        
    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.Y[idx]

# %%
glove=torchtext.vocab.GloVe(name='840B',dim=300)

# %%
train_dataset=TextDataset(glove,train)
 #each dataloader is a batch
train_dataloader = torch.utils.data.DataLoader(
        dataset=train_dataset, 
        batch_size=3, 
        shuffle=False, 
        collate_fn=lambda batch: my_collate_function(batch, 'cpu'))
# Out:
# original they're so adorable!!  L ["they're", 'so', 'adorable']
# original 19:33:57,travel far enough you meet yourself. L ['19', '33', '57', 'travel', 'far', 'enough', 'you', 'meet', 'yourself']
# original i interviewed michael saylor and asked him about:• ftx - what were the • ethical digital assets• bitcoin custody • bear market and cyclesmichael gave us a step by step breakdown. listen &amp; share  L ['i', 'interviewed', 'michael', 'saylor', 'and', 'asked', 'him', 'about', '•', 'ftx', '-', 'what', 'were', 'the', '•', 'ethical', 'digital', 'assets•', 'bitcoin', 'custody', '•', 'bear', 'market', 'and', 'cyclesmichael', 'gave', 'us', 'a', 'step', 'by', 'step', 'breakdown', 'listen', 'amp;', 'share']
# original since mid-90’s around 1995 or so (i was born in 1983 when marino started his career with the &amp; marino was my reason for cheering on the dolphins… still love him but now cheer the dolphins on for my “hawaii boy” (as i too am born &amp; raised in hawaii)  L ['since', 'mid-90’s', 'around', '1995', 'or', 'so', '(i', 'was', 'born', 'in', '1983', 'when', 'marino', 'started', 'his', 'career', 'with', 'the', 'amp;', 'marino', 'was', 'my', 'reason', 'for', 'cheering', 'on', 'the', 'dolphins…', 'still', 'love', 'him', 'but', 'now', 'cheer', 'the', 'dolphins', 'on', 'for', 'my', '“hawaii', 'boy”', '(as', 'i', 'too', 'am', 'born', 'amp;', 'raised', 'in', 'hawaii)']
# original congrats on winning the biggest ga ever reply your uid here please and screenshot the proof here, there is no more family discord, good luck on the next onewinner :  L ['congrats', 'on', 'winning', 'the', 'biggest', 'ga', 'ever', 'reply', 'your', 'uid', 'here', 'please', 'and', 'screenshot', 'the', 'proof', 'here', 'there', 'is', 'no', 'more', 'family', 'discord', 'good', 'luck', 'on', 'the', 'next', 'onewinner']
# original he's going to pelo  maalesef L ["he's", 'going', 'to', 'pelo', 'maalesef']
# original so vou se for no whats  L ['so', 'vou', 'se', 'for', 'no', 'whats']
# original "the means to an extraordinary life is tapped into the energy stream that will provide any form of means that you wanna talk about.so everyone is equally… has equal access to the means to an extraordinary life." abrahamhicks  L ['"the', 'means', 'to', 'an', 'extraordinary', 'life', 'is', 'tapped', 'into', 'the', 'energy', 'stream', 'that', 'will', 'provide', 'any', 'form', 'of', 'means', 'that', 'you', 'wanna', 'talk', 'about', 'so', 'everyone', 'is', 'equally…', 'has', 'equal', 'access', 'to', 'the', 'means', 'to', 'an', 'extraordinary', 'life', '"', 'abrahamhicks']
# original me so lucky  happy and blessed  L ['me', 'so', 'lucky', 'happy', 'and', 'blessed']
# original keep me up out now L ['keep', 'me', 'up', 'out', 'now']
# original  spotify premium murah readyinplan less bf1 bulan :15k2 bulan :25k3 bulan :35k4 bulan :45k6 bulan: 65k1 tahun :102k 100% trusted full garansi payment all e- wallet bca qris spay dll order dm/wa L ['spotify', 'premium', 'murah', 'readyinplan', 'less', 'bf1', 'bulan', '15k2', 'bulan', '25k3', 'bulan', '35k4', 'bulan', '45k6', 'bulan', '65k1', 'tahun', '102k', '100%', 'trusted', 'full', 'garansi', 'payment', 'all', 'e-', 'wallet', 'bca', 'qris', 'spay', 'dll', 'order', 'dm', 'wa']
# original 点头像咨询 there is no absolutely happy paradise in the world, only relatively people who can find their own happiness L ['点头像咨询', 'there', 'is', 'no', 'absolutely', 'happy', 'paradise', 'in', 'the', 'world', 'only', 'relatively', 'people', 'who', 'can', 'find', 'their', 'own', 'happiness']
# original oulike bleddie goed die jacks….. L ['oulike', 'bleddie', 'goed', 'die', 'jacks…']
# original if twitter dies you can find me: nowhere else lmao i barely maintain this account no way i'm making morebut seriously keep calm beans, all that's gonna happen is some things will be fucky for a while, elongated muskrat is gonna lose money and we're all going to be fine  L ['if', 'twitter', 'dies', 'you', 'can', 'find', 'me', 'nowhere', 'else', 'lmao', 'i', 'barely', 'maintain', 'this', 'account', 'no', 'way', "i'm", 'making', 'morebut', 'seriously', 'keep', 'calm', 'beans', 'all', "that's", 'gonna', 'happen', 'is', 'some', 'things', 'will', 'be', 'fucky', 'for', 'a', 'while', 'elongated', 'muskrat', 'is', 'gonna', 'lose', 'money', 'and', "we're", 'all', 'going', 'to', 'be', 'fine']
# original “pay it forward” in action, i love it. (great film btw) L ['“pay', 'it', 'forward”', 'in', 'action', 'i', 'love', 'it', '(great', 'film', 'btw)']
# original woot! hope makes sharing pics easier now that twitter going to be  L ['woot', 'hope', 'makes', 'sharing', 'pics', 'easier', 'now', 'that', 'twitter', 'going', 'to', 'be']
# original i can’t believe i done made it to szn 2 of abott elementary  omg great show  L ['i', 'can’t', 'believe', 'i', 'done', 'made', 'it', 'to', 'szn', '2', 'of', 'abott', 'elementary', 'omg', 'great', 'show']
# original guess i am not doxxing after all  L ['guess', 'i', 'am', 'not', 'doxxing', 'after', 'all']
# original immediately at this point L ['immediately', 'at', 'this', 'point']
# original find me on insta : fraudhi_see you there  L ['find', 'me', 'on', 'insta', 'fraudhi_see', 'you', 'there']
# original we own your airwaves!!! scatter my head by x | L ['we', 'own', 'your', 'airwaves', 'scatter', 'my', 'head', 'by', 'x']
# original omg drop the work out routine reigen L ['omg', 'drop', 'the', 'work', 'out', 'routine', 'reigen']
# original i-i never expected this it's just a simple concept but everyone is so sweet  L ['i-i', 'never', 'expected', 'this', "it's", 'just', 'a', 'simple', 'concept', 'but', 'everyone', 'is', 'so', 'sweet']
# original i love to take off from work, neglect my wife/kids, and down 3 redbulls so that i can be able to sit in a corner for 8 min and stream to my dead twitch channel don’t hate the player.. hate the game !  L ['i', 'love', 'to', 'take', 'off', 'from', 'work', 'neglect', 'my', 'wife', 'kids', 'and', 'down', '3', 'redbulls', 'so', 'that', 'i', 'can', 'be', 'able', 'to', 'sit', 'in', 'a', 'corner', 'for', '8', 'min', 'and', 'stream', 'to', 'my', 'dead', 'twitch', 'channel', 'don’t', 'hate', 'the', 'player', 'hate', 'the', 'game']
# original “family guy jm peter pouring a 4 in a two leader” hard lyric oat L ['“family', 'guy', 'jm', 'peter', 'pouring', 'a', '4', 'in', 'a', 'two', 'leader”', 'hard', 'lyric', 'oat']
# original outside ya city lookin good  L ['outside', 'ya', 'city', 'lookin', 'good']
# original yeah it’s not fun  L ['yeah', 'it’s', 'not', 'fun']
# original thanks for the cute letter and the gifts  L ['thanks', 'for', 'the', 'cute', 'letter', 'and', 'the', 'gifts']
# original paris, my dream destination.  L ['paris', 'my', 'dream', 'destination']
# original jai maa durge have a fantastic friday  L ['jai', 'maa', 'durge', 'have', 'a', 'fantastic', 'friday']
# original whazzup check this! excellent ?  L ['whazzup', 'check', 'this', 'excellent']
# original 7 years ,, okay L ['7', 'years', 'okay']
# original yes why not let’s do it right baby L ['yes', 'why', 'not', 'let’s', 'do', 'it', 'right', 'baby']
# original sent you a friend request  L ['sent', 'you', 'a', 'friend', 'request']
# original oh she’s just so  L ['oh', 'she’s', 'just', 'so']
# original since it sounds serious this time i made a tumblr!i'd love to have yall there L ['since', 'it', 'sounds', 'serious', 'this', 'time', 'i', 'made', 'a', 'tumblr', "i'd", 'love', 'to', 'have', 'yall', 'there']
# original my treasure my sweety honey bunny my masterpiece my everything!!!   L ['my', 'treasure', 'my', 'sweety', 'honey', 'bunny', 'my', 'masterpiece', 'my', 'everything']
# original observed weather at 5:00 pm  66ºf feels: 64ºf (↑70ºf at 3:33 pm )(↓51ºf at 7:19 am) 22ºf 18% 30.1 inhg (-0.0) 0 mph sse,  0 mph 9,957 ft 0.00 in L ['observed', 'weather', 'at', '5', '00', 'pm', '66ºf', 'feels', '64ºf', '(↑70ºf', 'at', '3', '33', 'pm', ')(↓51ºf', 'at', '7', '19', 'am)', '22ºf', '18%', '30', '1', 'inhg', '(-0', '0)', '0', 'mph', 'sse', '0', 'mph', '9', '957', 'ft', '0', '00', 'in']
# original good i'm not looking for apologies, i'm here to thank you for all the pain  but oh im glad it was nothing after all, and that was very smart to have a witness L ['good', "i'm", 'not', 'looking', 'for', 'apologies', "i'm", 'here', 'to', 'thank', 'you', 'for', 'all', 'the', 'pain', 'but', 'oh', 'im', 'glad', 'it', 'was', 'nothing', 'after', 'all', 'and', 'that', 'was', 'very', 'smart', 'to', 'have', 'a', 'witness']
# original .  a harlot tavern  a clerk  angela  a recreation L ['a', 'harlot', 'tavern', 'a', 'clerk', 'angela', 'a', 'recreation']
# original $0.47 | 7.000 idr ~ 5hours✓ follow ✓ rep pthanks  draw L ['0', '47', '7', '000', 'idr', '~', '5hours✓', 'follow', '✓', 'rep', 'pthanks', 'draw']
# original i had gotten to know fellow creators, sharing our creativity &amp; dnd stories adventures from this platformthank you if twitter goes away tomorrow, i would like to keep in touch with everyone here are my other platforms:instagram: fantasia_cosplay L ['i', 'had', 'gotten', 'to', 'know', 'fellow', 'creators', 'sharing', 'our', 'creativity', 'amp;', 'dnd', 'stories', 'adventures', 'from', 'this', 'platformthank', 'you', 'if', 'twitter', 'goes', 'away', 'tomorrow', 'i', 'would', 'like', 'to', 'keep', 'in', 'touch', 'with', 'everyone', 'here', 'are', 'my', 'other', 'platforms', 'instagram', 'fantasia_cosplay']
# original if you was ever head over hills bout me dont play crazy you will get exposed L ['if', 'you', 'was', 'ever', 'head', 'over', 'hills', 'bout', 'me', 'dont', 'play', 'crazy', 'you', 'will', 'get', 'exposed']
# original i love the fact that i'm wearing her bag sa pic na yon  L ['i', 'love', 'the', 'fact', 'that', "i'm", 'wearing', 'her', 'bag', 'sa', 'pic', 'na', 'yon']
# original ooooooh myyyyyy gooooood  i’m dying it’s so cute i want to hug shimo to sleep every night  L ['ooooooh', 'myyyyyy', 'gooooood', 'i’m', 'dying', 'it’s', 'so', 'cute', 'i', 'want', 'to', 'hug', 'shimo', 'to', 'sleep', 'every', 'night']
# original oh my god this edit looks so epic  L ['oh', 'my', 'god', 'this', 'edit', 'looks', 'so', 'epic']
# original banthover is not happy about the twitter situation  L ['banthover', 'is', 'not', 'happy', 'about', 'the', 'twitter', 'situation']
# original want to drive more traffic to your ? look at the stunning service: L ['want', 'to', 'drive', 'more', 'traffic', 'to', 'your', 'look', 'at', 'the', 'stunning', 'service']
# original no you’re just so pretty you distract from how bad i am at it i literally had this vision of a story i wanted to make for our anniversary and i had no idea how to put a song or bubbly collage i suuuuck hsgh but i love you L ['no', 'you’re', 'just', 'so', 'pretty', 'you', 'distract', 'from', 'how', 'bad', 'i', 'am', 'at', 'it', 'i', 'literally', 'had', 'this', 'vision', 'of', 'a', 'story', 'i', 'wanted', 'to', 'make', 'for', 'our', 'anniversary', 'and', 'i', 'had', 'no', 'idea', 'how', 'to', 'put', 'a', 'song', 'or', 'bubbly', 'collage', 'i', 'suuuuck', 'hsgh', 'but', 'i', 'love', 'you']
# original atiny !! reply with "  " and follow everyone who likes your reply L ['atiny', 'reply', 'with', '"', '"', 'and', 'follow', 'everyone', 'who', 'likes', 'your', 'reply']
# original thank you so much heather!! you’re very welcome my friend!!  L ['thank', 'you', 'so', 'much', 'heather', 'you’re', 'very', 'welcome', 'my', 'friend']
# original sky what a load of as per usual. L ['sky', 'what', 'a', 'load', 'of', 'as', 'per', 'usual']
# original this thread. this is why i love twitter. fucking elon..  L ['this', 'thread', 'this', 'is', 'why', 'i', 'love', 'twitter', 'fucking', 'elon']
# original she should anyway because our government is  right now L ['she', 'should', 'anyway', 'because', 'our', 'government', 'is', 'right', 'now']
# original sup do you check it? perfect !!!!  L ['sup', 'do', 'you', 'check', 'it', 'perfect']
# original this roddy rich album so fire L ['this', 'roddy', 'rich', 'album', 'so', 'fire']
# original  hey cyren!! i hope you have had pawsome birthday this year and i can’t wait to see you again soon because you’re such a good bean to all of us here in our community!! *hugs you!*   L ['hey', 'cyren', 'i', 'hope', 'you', 'have', 'had', 'pawsome', 'birthday', 'this', 'year', 'and', 'i', 'can’t', 'wait', 'to', 'see', 'you', 'again', 'soon', 'because', 'you’re', 'such', 'a', 'good', 'bean', 'to', 'all', 'of', 'us', 'here', 'in', 'our', 'community', 'hugs', 'you']
# original i think that’s what saw when the  went in the river  L ['i', 'think', 'that’s', 'what', 'saw', 'when', 'the', 'went', 'in', 'the', 'river']
# original i’m all set i will eat my grass fed meat instead  L ['i’m', 'all', 'set', 'i', 'will', 'eat', 'my', 'grass', 'fed', 'meat', 'instead']
# original 20:06:24to laugh at yourself is to love yourself. L ['20', '06', '24to', 'laugh', 'at', 'yourself', 'is', 'to', 'love', 'yourself']
# original be sure to give us a follow to stay up to date with our journey!  L ['be', 'sure', 'to', 'give', 'us', 'a', 'follow', 'to', 'stay', 'up', 'to', 'date', 'with', 'our', 'journey']
# original it’s twitter that may be lost  L ['it’s', 'twitter', 'that', 'may', 'be', 'lost']
# original ＃rissa ． since mio’s both a cloud and water nymph, i’ve been meaning to add a cloud into writing format, so i may start beginning replies like ..⠀⠀⠀⠀⠀ ཻུ۪۪. ٫ 𝓭extral is lifted to tuck white tresses behind ear .. L ['＃rissa', '．', 'since', 'mio’s', 'both', 'a', 'cloud', 'and', 'water', 'nymph', 'i’ve', 'been', 'meaning', 'to', 'add', 'a', 'cloud', 'into', 'writing', 'format', 'so', 'i', 'may', 'start', 'beginning', 'replies', 'like', '⠀⠀⠀⠀⠀', 'ཻུ۪۪', '٫', '𝓭extral', 'is', 'lifted', 'to', 'tuck', 'white', 'tresses', 'behind', 'ear']
# original hey cutie  uh uh i know this is sudden but would you like to come hangout with me on stream?  it would be even more fun with you there. L ['hey', 'cutie', 'uh', 'uh', 'i', 'know', 'this', 'is', 'sudden', 'but', 'would', 'you', 'like', 'to', 'come', 'hangout', 'with', 'me', 'on', 'stream', 'it', 'would', 'be', 'even', 'more', 'fun', 'with', 'you', 'there']
# original shame they won't be showcasing it L ['shame', 'they', "won't", 'be', 'showcasing', 'it']
# original good morning cutie kitty  L ['good', 'morning', 'cutie', 'kitty']
# original i know where you live so we're alright  L ['i', 'know', 'where', 'you', 'live', 'so', "we're", 'alright']
# original enter the holiday wish and win sweepstakes  L ['enter', 'the', 'holiday', 'wish', 'and', 'win', 'sweepstakes']
# original we are already moots there! L ['we', 'are', 'already', 'moots', 'there']
# original yay another anchovies girl.   L ['yay', 'another', 'anchovies', 'girl']
# original disini kak murcee, bisa qrisnetflix readymonth ๑ ˳ 1 bulan 1p1u : 27k ๑ ˳ 1 bulan 1p2u : 17kday ๑ ˳ 1 day 1u : 3k ๑ ˳ 3day 1u : 6kweek ๑ ˳ 1 minggu 1u : 10k bergaransi 100%, fast fixing dm or (fast res) 24 L ['disini', 'kak', 'murcee', 'bisa', 'qrisnetflix', 'readymonth', '๑', '˳', '1', 'bulan', '1p1u', '27k', '๑', '˳', '1', 'bulan', '1p2u', '17kday', '๑', '˳', '1', 'day', '1u', '3k', '๑', '˳', '3day', '1u', '6kweek', '๑', '˳', '1', 'minggu', '1u', '10k', 'bergaransi', '100%', 'fast', 'fixing', 'dm', 'or', '(fast', 'res)', '24']
# original stb oa @ livettention @ lllustation L ['stb', 'oa', '@', 'livettention', '@', 'lllustation']
# original seriously folks if you don't like nor free speech (no matter what side) then feel free to leave twitter. rediculus  L ['seriously', 'folks', 'if', 'you', "don't", 'like', 'nor', 'free', 'speech', '(no', 'matter', 'what', 'side)', 'then', 'feel', 'free', 'to', 'leave', 'twitter', 'rediculus']
# original never forget the cafeteria stink bombs L ['never', 'forget', 'the', 'cafeteria', 'stink', 'bombs']
# original rest well menace, hope you'll recover soon  L ['rest', 'well', 'menace', 'hope', "you'll", 'recover', 'soon']
# original for the culture! i love what he did with the joint trait - it's unique L ['for', 'the', 'culture', 'i', 'love', 'what', 'he', 'did', 'with', 'the', 'joint', 'trait', '-', "it's", 'unique']
# original i want to maintain contact or be able to contact artists/writers i follow and love in the fandom!if y’all wanna converse, i have my own little ofmd discord community server if anyone wants to come chat and share fanart/fics! it is lgbtq+/nsfw  L ['i', 'want', 'to', 'maintain', 'contact', 'or', 'be', 'able', 'to', 'contact', 'artists', 'writers', 'i', 'follow', 'and', 'love', 'in', 'the', 'fandom', 'if', 'y’all', 'wanna', 'converse', 'i', 'have', 'my', 'own', 'little', 'ofmd', 'discord', 'community', 'server', 'if', 'anyone', 'wants', 'to', 'come', 'chat', 'and', 'share', 'fanart', 'fics', 'it', 'is', 'lgbtq', 'nsfw']
# original so damn cute!!  L ['so', 'damn', 'cute']
# original good morning monika. thank you. have a fantastic friday! L ['good', 'morning', 'monika', 'thank', 'you', 'have', 'a', 'fantastic', 'friday']
# original  always a class act  L ['always', 'a', 'class', 'act']
# original why cant we have what they have  L ['why', 'cant', 'we', 'have', 'what', 'they', 'have']
# original i really hope twitter can ride out hurricane elon and things can stabilize. i love twitter’s eccentric communities. i’ve learned so much here &amp; met lovely new friends like you! so here’s hoping, my friend xo L ['i', 'really', 'hope', 'twitter', 'can', 'ride', 'out', 'hurricane', 'elon', 'and', 'things', 'can', 'stabilize', 'i', 'love', 'twitter’s', 'eccentric', 'communities', 'i’ve', 'learned', 'so', 'much', 'here', 'amp;', 'met', 'lovely', 'new', 'friends', 'like', 'you', 'so', 'here’s', 'hoping', 'my', 'friend', 'xo']
# original i am so incredibly thankful as well, meeting you is the best thing that happened to me this year! i'm so happy to have met you my lovely jie jie  L ['i', 'am', 'so', 'incredibly', 'thankful', 'as', 'well', 'meeting', 'you', 'is', 'the', 'best', 'thing', 'that', 'happened', 'to', 'me', 'this', 'year', "i'm", 'so', 'happy', 'to', 'have', 'met', 'you', 'my', 'lovely', 'jie', 'jie']
# original narrated 'umar bin al-khattab:i heard allah’s messenger ﷺ saying:“the reward of deeds depends upon the intentions and every person will get the reward according to what he has intended” sahih al-bukhari L ['narrated', "'umar", 'bin', 'al-khattab', 'i', 'heard', 'allah’s', 'messenger', 'ﷺ', 'saying', '“the', 'reward', 'of', 'deeds', 'depends', 'upon', 'the', 'intentions', 'and', 'every', 'person', 'will', 'get', 'the', 'reward', 'according', 'to', 'what', 'he', 'has', 'intended”', 'sahih', 'al-bukhari']
# original thank you for sharing! have a great evening, my friend!  L ['thank', 'you', 'for', 'sharing', 'have', 'a', 'great', 'evening', 'my', 'friend']
# original my man myyyy mannn  L ['my', 'man', 'myyyy', 'mannn']
# original why did josh hawley plot a coup &amp; a terrorist attack on our capitol then run like the chicken he is? L ['why', 'did', 'josh', 'hawley', 'plot', 'a', 'coup', 'amp;', 'a', 'terrorist', 'attack', 'on', 'our', 'capitol', 'then', 'run', 'like', 'the', 'chicken', 'he', 'is']
# original  according to up-skilling workers in the eu would result in a more productive &amp; competitive labour force, which would generate up to 200 billion euros per year by 2025  however, one of the growing concerns is skills validation, recognition, and transferability… L ['according', 'to', 'up-skilling', 'workers', 'in', 'the', 'eu', 'would', 'result', 'in', 'a', 'more', 'productive', 'amp;', 'competitive', 'labour', 'force', 'which', 'would', 'generate', 'up', 'to', '200', 'billion', 'euros', 'per', 'year', 'by', '2025', 'however', 'one', 'of', 'the', 'growing', 'concerns', 'is', 'skills', 'validation', 'recognition', 'and', 'transferability…']
# original well i'm going to sleep now...so if twitter really shuts down while i'm sleeping i want to say it was great meeting you all my fellow arashians ...hope we see each other again...i had a great time here...and if don't see you tomorrow!  byebye  L ['well', "i'm", 'going', 'to', 'sleep', 'now', 'so', 'if', 'twitter', 'really', 'shuts', 'down', 'while', "i'm", 'sleeping', 'i', 'want', 'to', 'say', 'it', 'was', 'great', 'meeting', 'you', 'all', 'my', 'fellow', 'arashians', 'hope', 'we', 'see', 'each', 'other', 'again', 'i', 'had', 'a', 'great', 'time', 'here', 'and', 'if', "don't", 'see', 'you', 'tomorrow', 'byebye']
# original ok thank u so much god bless  pakahassle mo elon L ['ok', 'thank', 'u', 'so', 'much', 'god', 'bless', 'pakahassle', 'mo', 'elon']
# original gmgm ruben  enjoy your friday  L ['gmgm', 'ruben', 'enjoy', 'your', 'friday']
# original if this place is goin down, catch me on tikkytokky and ig. both handles are shannonbrookeimagery  as well as here  L ['if', 'this', 'place', 'is', 'goin', 'down', 'catch', 'me', 'on', 'tikkytokky', 'and', 'ig', 'both', 'handles', 'are', 'shannonbrookeimagery', 'as', 'well', 'as', 'here']
# original 点头像咨询 consciousness is the mother of progress, and self abasement is the source of degeneration therefore, self abasement is indispensable L ['点头像咨询', 'consciousness', 'is', 'the', 'mother', 'of', 'progress', 'and', 'self', 'abasement', 'is', 'the', 'source', 'of', 'degeneration', 'therefore', 'self', 'abasement', 'is', 'indispensable']
# original follow me on ig  L ['follow', 'me', 'on', 'ig']
# original is anyone listening?  L ['is', 'anyone', 'listening']
# original &gt;\\\\\\\\\\w\\\\\\\\\\&lt; !? love you ~ hug kiss ~!! yes L ['gt;\\\\\\\\\\\\\\\\\\\\w\\\\\\\\\\\\\\\\\\\\', 'lt;', 'love', 'you', '~', 'hug', 'kiss', '~', 'yes']
# original oh baby, let me help you L ['oh', 'baby', 'let', 'me', 'help', 'you']
# original i love my wife  L ['i', 'love', 'my', 'wife']
# original hope it hasn’t all been too traumatic dude.  L ['hope', 'it', 'hasn’t', 'all', 'been', 'too', 'traumatic', 'dude']
# original you remind me of an ex. she’d get butterflies and smile every time i called her a cunt.. but then again, i would too.  L ['you', 'remind', 'me', 'of', 'an', 'ex', 'she’d', 'get', 'butterflies', 'and', 'smile', 'every', 'time', 'i', 'called', 'her', 'a', 'cunt', 'but', 'then', 'again', 'i', 'would', 'too']
# original has the best reaction  L ['has', 'the', 'best', 'reaction']
# original thank you from day 1. even though i am a lurker, i got to be exposed to so many amazing people.  L ['thank', 'you', 'from', 'day', '1', 'even', 'though', 'i', 'am', 'a', 'lurker', 'i', 'got', 'to', 'be', 'exposed', 'to', 'so', 'many', 'amazing', 'people']
# original $amznclosed below the ema$aaplclosed above the emaengulfing (outside bar)$googlclosed above the emad.setup 1-2-2$msftclosed above the emad.setup 1-2-2 L ['amznclosed', 'below', 'the', 'ema', 'aaplclosed', 'above', 'the', 'emaengulfing', '(outside', 'bar)', 'googlclosed', 'above', 'the', 'emad', 'setup', '1-2-2', 'msftclosed', 'above', 'the', 'emad', 'setup', '1-2-2']
# original want to shoot with me and embrace your sexy side - connect with me here!  L ['want', 'to', 'shoot', 'with', 'me', 'and', 'embrace', 'your', 'sexy', 'side', '-', 'connect', 'with', 'me', 'here']
# original odds are low but best of luck to me  L ['odds', 'are', 'low', 'but', 'best', 'of', 'luck', 'to', 'me']
# original packing be like, book and black abaya.done  L ['packing', 'be', 'like', 'book', 'and', 'black', 'abaya', 'done']
# original no, i did today!  L ['no', 'i', 'did', 'today']
# original fuck anus lick   anal lick sucking, fucking L ['fuck', 'anus', 'lick', 'anal', 'lick', 'sucking', 'fucking']
# original i can be his replacement i’m not as good looking but i may be sharper than bagley fantasy score  L ['i', 'can', 'be', 'his', 'replacement', 'i’m', 'not', 'as', 'good', 'looking', 'but', 'i', 'may', 'be', 'sharper', 'than', 'bagley', 'fantasy', 'score']
# original sun good morning and good mood :)) thank you dear L ['sun', 'good', 'morning', 'and', 'good', 'mood', '))', 'thank', 'you', 'dear']
# original what if we went to the cedar forest  L ['what', 'if', 'we', 'went', 'to', 'the', 'cedar', 'forest']
# original 点头像咨询 think carefully before making a decision once you have made a decision, go forward bravely L ['点头像咨询', 'think', 'carefully', 'before', 'making', 'a', 'decision', 'once', 'you', 'have', 'made', 'a', 'decision', 'go', 'forward', 'bravely']
# original so pretty!  lol!! :d  L ['so', 'pretty', 'lol', 'd']
# original fgs what's funny?  L ['fgs', "what's", 'funny']
# original have you an alternative platform superstar?  L ['have', 'you', 'an', 'alternative', 'platform', 'superstar']
# original you are so adorable! we love this photo  L ['you', 'are', 'so', 'adorable', 'we', 'love', 'this', 'photo']
# original nah man, my focus is primarily on football, other sports are secondary  L ['nah', 'man', 'my', 'focus', 'is', 'primarily', 'on', 'football', 'other', 'sports', 'are', 'secondary']
# original you got that . he is pretending to sit, "precariously" on the fence.  L ['you', 'got', 'that', 'he', 'is', 'pretending', 'to', 'sit', '"precariously"', 'on', 'the', 'fence']
# original this is so frustrating  ano tumblr mo? i'll try to make one rn, i'll follow u right away hehe L ['this', 'is', 'so', 'frustrating', 'ano', 'tumblr', 'mo', "i'll", 'try', 'to', 'make', 'one', 'rn', "i'll", 'follow', 'u', 'right', 'away', 'hehe']
# original 2 west coast scum bets for the dads and moms still awake! cal baptist +8 against undefeated pac 12 huskies. and nets +3 off and absolute blowout of 30 points. they are 6-9 and only catching 3 against 10-4 blazers in portland? go poop L ['2', 'west', 'coast', 'scum', 'bets', 'for', 'the', 'dads', 'and', 'moms', 'still', 'awake', 'cal', 'baptist', '8', 'against', 'undefeated', 'pac', '12', 'huskies', 'and', 'nets', '3', 'off', 'and', 'absolute', 'blowout', 'of', '30', 'points', 'they', 'are', '6-9', 'and', 'only', 'catching', '3', 'against', '10-4', 'blazers', 'in', 'portland', 'go', 'poop']
# original super hello!     i wanna boost my art skills give me your opinion, thanks! L ['super', 'hello', 'i', 'wanna', 'boost', 'my', 'art', 'skills', 'give', 'me', 'your', 'opinion', 'thanks']
# original no i’m sick of everything  L ['no', 'i’m', 'sick', 'of', 'everything']
# original hi everyonesex in riyadhass,analsucking, fucking L ['hi', 'everyonesex', 'in', 'riyadhass', 'analsucking', 'fucking']
# original this is both sad and relatable  L ['this', 'is', 'both', 'sad', 'and', 'relatable']
# original the only thing i’ll vote  for is to get u out that’s for sure  L ['the', 'only', 'thing', 'i’ll', 'vote', 'for', 'is', 'to', 'get', 'u', 'out', 'that’s', 'for', 'sure']
# original thank you so much L ['thank', 'you', 'so', 'much']
# original gm ! have a nice dayyyy  L ['gm', 'have', 'a', 'nice', 'dayyyy']
# original xoxo, gossip girl  L ['xoxo', 'gossip', 'girl']
# original amazing wor̡k. high quality and would recommend!  L ['amazing', 'wor̡k', 'high', 'quality', 'and', 'would', 'recommend']
# original imysmmark tuan the other side L ['imysmmark', 'tuan', 'the', 'other', 'side']
# original 9 programming principles every programmer must know!(1/n)a thread   L ['9', 'programming', 'principles', 'every', 'programmer', 'must', 'know', '(1', 'n)a', 'thread']
# original people been saying it's starting to glitch and shut down agdhajja need to tell you i love you all  L ['people', 'been', 'saying', "it's", 'starting', 'to', 'glitch', 'and', 'shut', 'down', 'agdhajja', 'need', 'to', 'tell', 'you', 'i', 'love', 'you', 'all']
# original add jin in there and that's my bias line L ['add', 'jin', 'in', 'there', 'and', "that's", 'my', 'bias', 'line']
# original thank you for you!  L ['thank', 'you', 'for', 'you']
# original    new podcast! looking for more content?look no further!your journey awaits... L ['new', 'podcast', 'looking', 'for', 'more', 'content', 'look', 'no', 'further', 'your', 'journey', 'awaits']
# original this is super one buddy,  L ['this', 'is', 'super', 'one', 'buddy']
# original no daily deliveries in norway. not only is it bad for posties, it's a frankly crap service for customers too. they're going on strike for their t&amp;cs, and for your quality of service too.  L ['no', 'daily', 'deliveries', 'in', 'norway', 'not', 'only', 'is', 'it', 'bad', 'for', 'posties', "it's", 'a', 'frankly', 'crap', 'service', 'for', 'customers', 'too', "they're", 'going', 'on', 'strike', 'for', 'their', 't', 'amp;cs', 'and', 'for', 'your', 'quality', 'of', 'service', 'too']
# original netflix premium 4k7 days : 35฿30 days : 98฿จอส่วนตัว/รับเคลม/แอคไทยorder : dmwallet | bank:;) q L ['netflix', 'premium', '4k7', 'days', '35฿30', 'days', '98฿จอส่วนตัว', 'รับเคลม', 'แอคไทยorder', 'dmwallet', 'bank', ';)', 'q']
# original thundersnow storm in buffalo  L ['thundersnow', 'storm', 'in', 'buffalo']
# original let's follow each other once again L ["let's", 'follow', 'each', 'other', 'once', 'again']
# original whole lot of crazy shit going on rn, but atleast im going to see ateez tomorrow!! back to reality after my birthday though i just want to enjoy my 21st L ['whole', 'lot', 'of', 'crazy', 'shit', 'going', 'on', 'rn', 'but', 'atleast', 'im', 'going', 'to', 'see', 'ateez', 'tomorrow', 'back', 'to', 'reality', 'after', 'my', 'birthday', 'though', 'i', 'just', 'want', 'to', 'enjoy', 'my', '21st']
# original they are all one  L ['they', 'are', 'all', 'one']
# original girllll i heard those bidets can be fierce!  but very hygienic  L ['girllll', 'i', 'heard', 'those', 'bidets', 'can', 'be', 'fierce', 'but', 'very', 'hygienic']
# original no one talk to me im gonna be thinking and watching malvina monroe all day  L ['no', 'one', 'talk', 'to', 'me', 'im', 'gonna', 'be', 'thinking', 'and', 'watching', 'malvina', 'monroe', 'all', 'day']
# original damn i was never able to buy my twitter crush flowers  L ['damn', 'i', 'was', 'never', 'able', 'to', 'buy', 'my', 'twitter', 'crush', 'flowers']
# original unfair comparison. there’s a couple of folks in that monday law side that can father the entire accumulators squad L ['unfair', 'comparison', 'there’s', 'a', 'couple', 'of', 'folks', 'in', 'that', 'monday', 'law', 'side', 'that', 'can', 'father', 'the', 'entire', 'accumulators', 'squad']
# original may you also experience same  L ['may', 'you', 'also', 'experience', 'same']
# original he absolutely refused to let me in the macbook so i broke it  L ['he', 'absolutely', 'refused', 'to', 'let', 'me', 'in', 'the', 'macbook', 'so', 'i', 'broke', 'it']
# original i’ll follow u back queen  L ['i’ll', 'follow', 'u', 'back', 'queen']
# original oh damn you’re right  there’s the joker L ['oh', 'damn', 'you’re', 'right', 'there’s', 'the', 'joker']
# original thats it for now, these just made me laugh  L ['thats', 'it', 'for', 'now', 'these', 'just', 'made', 'me', 'laugh']
# original the torys have yet and yet another plan  L ['the', 'torys', 'have', 'yet', 'and', 'yet', 'another', 'plan']
# original love you about you talent you arepure ten L ['love', 'you', 'about', 'you', 'talent', 'you', 'arepure', 'ten']
# original mclove of my life  L ['mclove', 'of', 'my', 'life']
# original seat plan and ticket price reveal naman dyan for hslot mnl oh  L ['seat', 'plan', 'and', 'ticket', 'price', 'reveal', 'naman', 'dyan', 'for', 'hslot', 'mnl', 'oh']
# original exactly brother bear, ke batla lunch  L ['exactly', 'brother', 'bear', 'ke', 'batla', 'lunch']
# original he don’t kno arguing turn me on  L ['he', 'don’t', 'kno', 'arguing', 'turn', 'me', 'on']
# original are those 'hair' tattoo'd on her thighs? L ['are', 'those', "'hair'", "tattoo'd", 'on', 'her', 'thighs']
# original is going down i think  my account is automatically disabled L ['is', 'going', 'down', 'i', 'think', 'my', 'account', 'is', 'automatically', 'disabled']
# original heres a faster way.... ftx's financials showed that there was a "back door" in the books, created with "bespoke software," according to reuters. it was described as a way that bankman-fried could alter the firm's financial records without raising any alerts. till he got caught L ['heres', 'a', 'faster', 'way', "ftx's", 'financials', 'showed', 'that', 'there', 'was', 'a', '"back', 'door"', 'in', 'the', 'books', 'created', 'with', '"bespoke', 'software', '"', 'according', 'to', 'reuters', 'it', 'was', 'described', 'as', 'a', 'way', 'that', 'bankman-fried', 'could', 'alter', 'the', "firm's", 'financial', 'records', 'without', 'raising', 'any', 'alerts', 'till', 'he', 'got', 'caught']
# original always the little things mate! classic  L ['always', 'the', 'little', 'things', 'mate', 'classic']
# original i will participate with this great project  L ['i', 'will', 'participate', 'with', 'this', 'great', 'project']
# original hi princess!!! i’m good now that i’m able to tweet! it sucks not being able to all day especially on a day off!!!  how are you??  L ['hi', 'princess', 'i’m', 'good', 'now', 'that', 'i’m', 'able', 'to', 'tweet', 'it', 'sucks', 'not', 'being', 'able', 'to', 'all', 'day', 'especially', 'on', 'a', 'day', 'off', 'how', 'are', 'you']
# original now playing  kevin knapp - heads up  L ['now', 'playing', 'kevin', 'knapp', '-', 'heads', 'up']
# original i seem to remember lsg saying how hook is his family himself so are you saying the very person you claim to love, cherish, &amp; adore is an idiot??  woooooow… y’all know he put everything into that company. this behavior is cringe af  L ['i', 'seem', 'to', 'remember', 'lsg', 'saying', 'how', 'hook', 'is', 'his', 'family', 'himself', 'so', 'are', 'you', 'saying', 'the', 'very', 'person', 'you', 'claim', 'to', 'love', 'cherish', 'amp;', 'adore', 'is', 'an', 'idiot', 'woooooow…', 'y’all', 'know', 'he', 'put', 'everything', 'into', 'that', 'company', 'this', 'behavior', 'is', 'cringe', 'af']
# original don't mind bro !! this is frustration page. !! frustrated sallapam  L ["don't", 'mind', 'bro', 'this', 'is', 'frustration', 'page', 'frustrated', 'sallapam']
# original  all of you… why…?! why’d you have to barge into my heart like that? why won't you leave me alone…?! why does it make my heart ache so much to hear you say that…?! L ['all', 'of', 'you…', 'why…', 'why’d', 'you', 'have', 'to', 'barge', 'into', 'my', 'heart', 'like', 'that', 'why', "won't", 'you', 'leave', 'me', 'alone…', 'why', 'does', 'it', 'make', 'my', 'heart', 'ache', 'so', 'much', 'to', 'hear', 'you', 'say', 'that…']
# original nadia…. the most beautiful, intelligent, amazing drama artist in the world. stay blessed ever  L ['nadia…', 'the', 'most', 'beautiful', 'intelligent', 'amazing', 'drama', 'artist', 'in', 'the', 'world', 'stay', 'blessed', 'ever']
# original ugh! those darn kids keeping secrets again!    L ['ugh', 'those', 'darn', 'kids', 'keeping', 'secrets', 'again']
# original how bloody gorgeous is this!!  L ['how', 'bloody', 'gorgeous', 'is', 'this']
# original .......... feed me more tkin  lol imma join you L ['feed', 'me', 'more', 'tkin', 'lol', 'imma', 'join', 'you']
# original guessing you had a crack at it then  L ['guessing', 'you', 'had', 'a', 'crack', 'at', 'it', 'then']
# original love you too. without halitwitter i wouldn't have "met" you. would miss you if we didn't have this platform. i too think about things differently; thank you for that L ['love', 'you', 'too', 'without', 'halitwitter', 'i', "wouldn't", 'have', '"met"', 'you', 'would', 'miss', 'you', 'if', 'we', "didn't", 'have', 'this', 'platform', 'i', 'too', 'think', 'about', 'things', 'differently;', 'thank', 'you', 'for', 'that']
# original it’s weird that these videos aren’t cute for me ? L ['it’s', 'weird', 'that', 'these', 'videos', 'aren’t', 'cute', 'for', 'me']
# original : the fact that ‘true love’ is able to go this far allows me to have motivation and it’s a form support to me who wants to continue to walk down this path  (4/4) L ['the', 'fact', 'that', '‘true', 'love’', 'is', 'able', 'to', 'go', 'this', 'far', 'allows', 'me', 'to', 'have', 'motivation', 'and', 'it’s', 'a', 'form', 'support', 'to', 'me', 'who', 'wants', 'to', 'continue', 'to', 'walk', 'down', 'this', 'path', '(4', '4)']
# original i dey beside your house like this  L ['i', 'dey', 'beside', 'your', 'house', 'like', 'this']
# original what i look like sittin back idly while someone continues to lie to me in my face  i’ll tell ya what, i’d look like a retarded dumb ahh  L ['what', 'i', 'look', 'like', 'sittin', 'back', 'idly', 'while', 'someone', 'continues', 'to', 'lie', 'to', 'me', 'in', 'my', 'face', 'i’ll', 'tell', 'ya', 'what', 'i’d', 'look', 'like', 'a', 'retarded', 'dumb', 'ahh']
# original sir , lucknow express me birthday party  L ['sir', 'lucknow', 'express', 'me', 'birthday', 'party']
# original hahaha oh i do too, don’t worry!  L ['hahaha', 'oh', 'i', 'do', 'too', 'don’t', 'worry']
# original i follow back asap  L ['i', 'follow', 'back', 'asap']
# original you have the most magical energy babe  L ['you', 'have', 'the', 'most', 'magical', 'energy', 'babe']
# original need some upbeat escapism today? treat your eardrums to headphones  it's about how we can create a world of our very own whenever we put our headphones on. i played electric guitar on it. i like it a lot. listen here  L ['need', 'some', 'upbeat', 'escapism', 'today', 'treat', 'your', 'eardrums', 'to', 'headphones', "it's", 'about', 'how', 'we', 'can', 'create', 'a', 'world', 'of', 'our', 'very', 'own', 'whenever', 'we', 'put', 'our', 'headphones', 'on', 'i', 'played', 'electric', 'guitar', 'on', 'it', 'i', 'like', 'it', 'a', 'lot', 'listen', 'here']
# original jieun thank you for being a part of the group, we'll miss you dearly and hope you get better, wish you the best L ['jieun', 'thank', 'you', 'for', 'being', 'a', 'part', 'of', 'the', 'group', "we'll", 'miss', 'you', 'dearly', 'and', 'hope', 'you', 'get', 'better', 'wish', 'you', 'the', 'best']
# original a lot still available!! come come price negotiable nii  L ['a', 'lot', 'still', 'available', 'come', 'come', 'price', 'negotiable', 'nii']
# original i agree, i’ve set up a mastodon account plus my instagram - any other alternatives you can think of? because i can’t see me hanging around here much longer  L ['i', 'agree', 'i’ve', 'set', 'up', 'a', 'mastodon', 'account', 'plus', 'my', 'instagram', '-', 'any', 'other', 'alternatives', 'you', 'can', 'think', 'of', 'because', 'i', 'can’t', 'see', 'me', 'hanging', 'around', 'here', 'much', 'longer']
# original [ wts ]  skz maxident pobs all pobs price exc local postage only mmt ( rm30 ea )⁃ cb x 2 music korea ( rm45 ea )⁃ sm namil ( rm38 ea )⁃ sm , cb starriver vc 2.0 ( rm40 ea )⁃ lk + cb sw offline ld event 1 ( rm38 ea )⁃ cb L ['[', 'wts', ']', 'skz', 'maxident', 'pobs', 'all', 'pobs', 'price', 'exc', 'local', 'postage', 'only', 'mmt', '(', 'rm30', 'ea', ')⁃', 'cb', 'x', '2', 'music', 'korea', '(', 'rm45', 'ea', ')⁃', 'sm', 'namil', '(', 'rm38', 'ea', ')⁃', 'sm', 'cb', 'starriver', 'vc', '2', '0', '(', 'rm40', 'ea', ')⁃', 'lk', 'cb', 'sw', 'offline', 'ld', 'event', '1', '(', 'rm38', 'ea', ')⁃', 'cb']
# original and tony, they will as long as those support guy, smith and dutton. they are doing us a great favour. L ['and', 'tony', 'they', 'will', 'as', 'long', 'as', 'those', 'support', 'guy', 'smith', 'and', 'dutton', 'they', 'are', 'doing', 'us', 'a', 'great', 'favour']
# original the whole debacle shoukd be thrown out, and should be made to remove herself from any oversight. ridiculous on its face n insulting to the thousands of people who witnessed and endured this chaotic voting day mess L ['the', 'whole', 'debacle', 'shoukd', 'be', 'thrown', 'out', 'and', 'should', 'be', 'made', 'to', 'remove', 'herself', 'from', 'any', 'oversight', 'ridiculous', 'on', 'its', 'face', 'n', 'insulting', 'to', 'the', 'thousands', 'of', 'people', 'who', 'witnessed', 'and', 'endured', 'this', 'chaotic', 'voting', 'day', 'mess']
# original lets go to tumblr luka,  L ['lets', 'go', 'to', 'tumblr', 'luka']
# original  what in the actual f*ck!!!!???? L ['what', 'in', 'the', 'actual', 'f', 'ck']
# original the truth is none of us know what will happen in the near future, but it is best to be proactive.good luck to us all and the platform. i truly hope that things are just a bit out of sorts for the moment and that the dust will settle soon. L ['the', 'truth', 'is', 'none', 'of', 'us', 'know', 'what', 'will', 'happen', 'in', 'the', 'near', 'future', 'but', 'it', 'is', 'best', 'to', 'be', 'proactive', 'good', 'luck', 'to', 'us', 'all', 'and', 'the', 'platform', 'i', 'truly', 'hope', 'that', 'things', 'are', 'just', 'a', 'bit', 'out', 'of', 'sorts', 'for', 'the', 'moment', 'and', 'that', 'the', 'dust', 'will', 'settle', 'soon']
# original aaa followed you there !!mine is still @ parjuny  will try to post more  L ['aaa', 'followed', 'you', 'there', 'mine', 'is', 'still', '@', 'parjuny', 'will', 'try', 'to', 'post', 'more']
# original today at 11am utc, i'll be attending the loozr incentivized testnet: bolt v1.0 event. join by clicking here:  L ['today', 'at', '11am', 'utc', "i'll", 'be', 'attending', 'the', 'loozr', 'incentivized', 'testnet', 'bolt', 'v1', '0', 'event', 'join', 'by', 'clicking', 'here']
# original thanks for the alpha  L ['thanks', 'for', 'the', 'alpha']
# original ohh my lord!  what i would do to have you reverse face fook me!  L ['ohh', 'my', 'lord', 'what', 'i', 'would', 'do', 'to', 'have', 'you', 'reverse', 'face', 'fook', 'me']
# original your welcome.... fighting together next time  L ['your', 'welcome', 'fighting', 'together', 'next', 'time']
# original every server is another house. curtains tight close. you can't see anyone unless you know their complete adress and ring their door. L ['every', 'server', 'is', 'another', 'house', 'curtains', 'tight', 'close', 'you', "can't", 'see', 'anyone', 'unless', 'you', 'know', 'their', 'complete', 'adress', 'and', 'ring', 'their', 'door']
# original okay so yes i am definitely allergic to pineapple  L ['okay', 'so', 'yes', 'i', 'am', 'definitely', 'allergic', 'to', 'pineapple']
# original i know i should, and i also know that sometimes i'm not even annoying them. anxiety just sucks  L ['i', 'know', 'i', 'should', 'and', 'i', 'also', 'know', 'that', 'sometimes', "i'm", 'not', 'even', 'annoying', 'them', 'anxiety', 'just', 'sucks']
# original india vs new zealand live𝐋𝐈𝐕𝐄 link➤ road warriors vs columbian dyip𝐋𝐈𝐕𝐄 link➤ ginebra vs blackwater𝐋𝐈𝐕𝐄 link➤ 10 L ['india', 'vs', 'new', 'zealand', 'live𝐋𝐈𝐕𝐄', 'link➤', 'road', 'warriors', 'vs', 'columbian', 'dyip𝐋𝐈𝐕𝐄', 'link➤', 'ginebra', 'vs', 'blackwater𝐋𝐈𝐕𝐄', 'link➤', '10']
# original thank you dear laini! a very beautiful work! L ['thank', 'you', 'dear', 'laini', 'a', 'very', 'beautiful', 'work']
# original pretty bootyhole,phat pussy  L ['pretty', 'bootyhole', 'phat', 'pussy']
# original its so sad to see how some of the fans treat her tho L ['its', 'so', 'sad', 'to', 'see', 'how', 'some', 'of', 'the', 'fans', 'treat', 'her', 'tho']
# original morning lindsay, looking pretty bleak isn’t it. all those words and glorified promises -   L ['morning', 'lindsay', 'looking', 'pretty', 'bleak', 'isn’t', 'it', 'all', 'those', 'words', 'and', 'glorified', 'promises', '-']
# original i be checking my phone like someone cares about me lol  L ['i', 'be', 'checking', 'my', 'phone', 'like', 'someone', 'cares', 'about', 'me', 'lol']
# original my colleague just got her tickets for the blackpink concert yayyyyy  L ['my', 'colleague', 'just', 'got', 'her', 'tickets', 'for', 'the', 'blackpink', 'concert', 'yayyyyy']
# original i use purple hearts with everyone. today i just saw that my cowoker replied to me with purple heart. i am transforming everyone into purple heart users.  L ['i', 'use', 'purple', 'hearts', 'with', 'everyone', 'today', 'i', 'just', 'saw', 'that', 'my', 'cowoker', 'replied', 'to', 'me', 'with', 'purple', 'heart', 'i', 'am', 'transforming', 'everyone', 'into', 'purple', 'heart', 'users']
# original i don’t get why she can’t mind her own business did she get elected to come on twitter to showboat L ['i', 'don’t', 'get', 'why', 'she', 'can’t', 'mind', 'her', 'own', 'business', 'did', 'she', 'get', 'elected', 'to', 'come', 'on', 'twitter', 'to', 'showboat']
# original we couldvd been engineers together  L ['we', 'couldvd', 'been', 'engineers', 'together']
# original good morning beautiful maggie, echo and odetta.have a pawsome friday and weekend. stay safe. love you.  L ['good', 'morning', 'beautiful', 'maggie', 'echo', 'and', 'odetta', 'have', 'a', 'pawsome', 'friday', 'and', 'weekend', 'stay', 'safe', 'love', 'you']
# original winner :  2nd winner plz post btc paypal cashapp below!! L ['winner', '2nd', 'winner', 'plz', 'post', 'btc', 'paypal', 'cashapp', 'below']
# original what do you mean twitter is shutting down?!  L ['what', 'do', 'you', 'mean', 'twitter', 'is', 'shutting', 'down']
# original i came for the t-shirts and stayed for the community. i hope we can regroup elsewhere  L ['i', 'came', 'for', 'the', 't-shirts', 'and', 'stayed', 'for', 'the', 'community', 'i', 'hope', 'we', 'can', 'regroup', 'elsewhere']
# original one last time since the app is dying. who was wrong kwi acrimony?  L ['one', 'last', 'time', 'since', 'the', 'app', 'is', 'dying', 'who', 'was', 'wrong', 'kwi', 'acrimony']
# original bye guys. i love and all of you  L ['bye', 'guys', 'i', 'love', 'and', 'all', 'of', 'you']
# original you rocked it!!!!!!! completely the right chords!!!! i love this very much  L ['you', 'rocked', 'it', 'completely', 'the', 'right', 'chords', 'i', 'love', 'this', 'very', 'much']
# original one thing my boyfriend will do, is call me to debrief after he’s been to groove  L ['one', 'thing', 'my', 'boyfriend', 'will', 'do', 'is', 'call', 'me', 'to', 'debrief', 'after', 'he’s', 'been', 'to', 'groove']
# original hulk died to me in infinity war  L ['hulk', 'died', 'to', 'me', 'in', 'infinity', 'war']
# original none whatsoever you gotta let it out to have your brain working properly  L ['none', 'whatsoever', 'you', 'gotta', 'let', 'it', 'out', 'to', 'have', 'your', 'brain', 'working', 'properly']
# original i have  to hold me over for at least like 2 months L ['i', 'have', 'to', 'hold', 'me', 'over', 'for', 'at', 'least', 'like', '2', 'months']
# original thanks a million.thank you  L ['thanks', 'a', 'million', 'thank', 'you']
# original yup, all that matters  L ['yup', 'all', 'that', 'matters']
# original retweet let's follow you  L ['retweet', "let's", 'follow', 'you']
# original winner : congrats! please dm to claim your prize  L ['winner', 'congrats', 'please', 'dm', 'to', 'claim', 'your', 'prize']
# original thank you so much dear good morning to you  L ['thank', 'you', 'so', 'much', 'dear', 'good', 'morning', 'to', 'you']
# original it won’t be a surprise when ghana  win this trophy  .anaa  L ['it', 'won’t', 'be', 'a', 'surprise', 'when', 'ghana', 'win', 'this', 'trophy', 'anaa']
# original  good eve luvs, ate raelle here! i’m open for autocad and sketchup comms! (rush &amp; non rush)  dm for inquiries services offered:•floor plan•elevations•foundation plan•3d models•architectural plan •structural plan•isometric/orthographic figures L ['good', 'eve', 'luvs', 'ate', 'raelle', 'here', 'i’m', 'open', 'for', 'autocad', 'and', 'sketchup', 'comms', '(rush', 'amp;', 'non', 'rush)', 'dm', 'for', 'inquiries', 'services', 'offered', '•floor', 'plan•elevations•foundation', 'plan•3d', 'models•architectural', 'plan', '•structural', 'plan•isometric', 'orthographic', 'figures']
# original my favourite character is xiao  but genshin has so many nice characters and i like lots of them  L ['my', 'favourite', 'character', 'is', 'xiao', 'but', 'genshin', 'has', 'so', 'many', 'nice', 'characters', 'and', 'i', 'like', 'lots', 'of', 'them']
# original done and thank you  L ['done', 'and', 'thank', 'you']
# original he’s so so sexy  L ['he’s', 'so', 'so', 'sexy']
# original india vs new zealand live𝐋𝐈𝐕𝐄 link➤ road warriors vs columbian dyip𝐋𝐈𝐕𝐄 link➤ ginebra vs blackwater𝐋𝐈𝐕𝐄 link➤ a L ['india', 'vs', 'new', 'zealand', 'live𝐋𝐈𝐕𝐄', 'link➤', 'road', 'warriors', 'vs', 'columbian', 'dyip𝐋𝐈𝐕𝐄', 'link➤', 'ginebra', 'vs', 'blackwater𝐋𝐈𝐕𝐄', 'link➤', 'a']
# original sad to say but get used to seeing stories like this.  L ['sad', 'to', 'say', 'but', 'get', 'used', 'to', 'seeing', 'stories', 'like', 'this']
# original can attest to this. even sa ibang concerts. maya is very efficient  L ['can', 'attest', 'to', 'this', 'even', 'sa', 'ibang', 'concerts', 'maya', 'is', 'very', 'efficient']
# original world best is back and better alihamdulilahi  L ['world', 'best', 'is', 'back', 'and', 'better', 'alihamdulilahi']
# original these are my other favorite twitter accounts   L ['these', 'are', 'my', 'other', 'favorite', 'twitter', 'accounts']
# ...
# original well if y’all wanna find me, my insta is the best place  @ emii.wii L ['well', 'if', 'y’all', 'wanna', 'find', 'me', 'my', 'insta', 'is', 'the', 'best', 'place', '@', 'emii', 'wii']
# original there's many poor here on this app. L ["there's", 'many', 'poor', 'here', 'on', 'this', 'app']
# original it’s been a pleasure mate  L ['it’s', 'been', 'a', 'pleasure', 'mate']
# original yes, snowpanda143_mewlions and snowpanda143_formew please post your handles too, and tiktok if you have it  L ['yes', 'snowpanda143_mewlions', 'and', 'snowpanda143_formew', 'please', 'post', 'your', 'handles', 'too', 'and', 'tiktok', 'if', 'you', 'have', 'it']
# original bill shatner is and always will be a legend. george is a  L ['bill', 'shatner', 'is', 'and', 'always', 'will', 'be', 'a', 'legend', 'george', 'is', 'a']
# original i'm channeling all my positive energy for this site  L ["i'm", 'channeling', 'all', 'my', 'positive', 'energy', 'for', 'this', 'site']
# original its fun bullying me L ['its', 'fun', 'bullying', 'me']
# original same - you guys are what i would i would miss. 2/3 rds of my replies aren’t getting served now - just repeated error messages  L ['same', '-', 'you', 'guys', 'are', 'what', 'i', 'would', 'i', 'would', 'miss', '2', '3', 'rds', 'of', 'my', 'replies', 'aren’t', 'getting', 'served', 'now', '-', 'just', 'repeated', 'error', 'messages']
# original he flies a private jet you muppet also large part of his wealth comes from apartheid and cheating. space x is impressive but he is a toxic narcissistic sadist L ['he', 'flies', 'a', 'private', 'jet', 'you', 'muppet', 'also', 'large', 'part', 'of', 'his', 'wealth', 'comes', 'from', 'apartheid', 'and', 'cheating', 'space', 'x', 'is', 'impressive', 'but', 'he', 'is', 'a', 'toxic', 'narcissistic', 'sadist']
# original good morning! wishing the same for you!!  L ['good', 'morning', 'wishing', 'the', 'same', 'for', 'you']
# original never would i or ever give up my as a dad husband or uncle. to live the life u have. sorry for your luck . u must know by now money is the lost world and fam o is the life of gift  L ['never', 'would', 'i', 'or', 'ever', 'give', 'up', 'my', 'as', 'a', 'dad', 'husband', 'or', 'uncle', 'to', 'live', 'the', 'life', 'u', 'have', 'sorry', 'for', 'your', 'luck', 'u', 'must', 'know', 'by', 'now', 'money', 'is', 'the', 'lost', 'world', 'and', 'fam', 'o', 'is', 'the', 'life', 'of', 'gift']
# original greetings from afar but from the heart L ['greetings', 'from', 'afar', 'but', 'from', 'the', 'heart']
# original skylar grey - kill for you (official audio) ft. eminem L ['skylar', 'grey', '-', 'kill', 'for', 'you', '(official', 'audio)', 'ft', 'eminem']
# original oh, and (at least) once more for the road:  L ['oh', 'and', '(at', 'least)', 'once', 'more', 'for', 'the', 'road']
# original 点头像咨询 ideals are like stars, pointing the way forward in the dark chaos L ['点头像咨询', 'ideals', 'are', 'like', 'stars', 'pointing', 'the', 'way', 'forward', 'in', 'the', 'dark', 'chaos']
# original when you start at rock bottom  the only place  you can go  is up  L ['when', 'you', 'start', 'at', 'rock', 'bottom', 'the', 'only', 'place', 'you', 'can', 'go', 'is', 'up']
# original at least i didn’t start him on draftkings whew!fanduel is ruined  L ['at', 'least', 'i', 'didn’t', 'start', 'him', 'on', 'draftkings', 'whew', 'fanduel', 'is', 'ruined']
# original me i slept well o, wahala for married couples o L ['me', 'i', 'slept', 'well', 'o', 'wahala', 'for', 'married', 'couples', 'o']
# original silicon tetrachloride  ricin is incoherents. L ['silicon', 'tetrachloride', 'ricin', 'is', 'incoherents']
# original good morning !! haaavee a nice fridayyy &lt;33  L ['good', 'morning', 'haaavee', 'a', 'nice', 'fridayyy', 'lt;33']
# original someone please help me find a three bedroom self contain house at east legon to rent  L ['someone', 'please', 'help', 'me', 'find', 'a', 'three', 'bedroom', 'self', 'contain', 'house', 'at', 'east', 'legon', 'to', 'rent']
# original this gave me goosebumps. mo u egyptian king  L ['this', 'gave', 'me', 'goosebumps', 'mo', 'u', 'egyptian', 'king']
# original no im not an areum po  L ['no', 'im', 'not', 'an', 'areum', 'po']
# original people marry things like this L ['people', 'marry', 'things', 'like', 'this']
# original just keep looking to the stars  L ['just', 'keep', 'looking', 'to', 'the', 'stars']
# original i thought y’all were exclusive  L ['i', 'thought', 'y’all', 'were', 'exclusive']
# original not jealous at all  L ['not', 'jealous', 'at', 'all']
# original morning18 bambam  have a fabulous day with wheels up, slow mo &amp; who are you by bambam  L ['morning18', 'bambam', 'have', 'a', 'fabulous', 'day', 'with', 'wheels', 'up', 'slow', 'mo', 'amp;', 'who', 'are', 'you', 'by', 'bambam']
# original amazing sweet job for doing this!happy morphinominal fall/autumn birthday! stay cool and warm! hope your special day is amazing as you! keep on being you!  L ['amazing', 'sweet', 'job', 'for', 'doing', 'this', 'happy', 'morphinominal', 'fall', 'autumn', 'birthday', 'stay', 'cool', 'and', 'warm', 'hope', 'your', 'special', 'day', 'is', 'amazing', 'as', 'you', 'keep', 'on', 'being', 'you']
# original seasons of beauty, leaf by leaf.  L ['seasons', 'of', 'beauty', 'leaf', 'by', 'leaf']
# original 19:40:10to laugh at yourself is to love yourself. L ['19', '40', '10to', 'laugh', 'at', 'yourself', 'is', 'to', 'love', 'yourself']
# original whyyyyy is everyone on andor so hard to understand? i didn’t understand a single thing the alien said or luthen’s convo to . i don’t have this issue with any other show. L ['whyyyyy', 'is', 'everyone', 'on', 'andor', 'so', 'hard', 'to', 'understand', 'i', 'didn’t', 'understand', 'a', 'single', 'thing', 'the', 'alien', 'said', 'or', 'luthen’s', 'convo', 'to', 'i', 'don’t', 'have', 'this', 'issue', 'with', 'any', 'other', 'show']
# original ~ ‘“it would be a political mistake, a geopolitical mistake, a strategic mistake,” says mark milley…’ top us general: china invading taiwan a 'mistake' like russia in ukraine L ['~', '‘“it', 'would', 'be', 'a', 'political', 'mistake', 'a', 'geopolitical', 'mistake', 'a', 'strategic', 'mistake', '”', 'says', 'mark', 'milley…’', 'top', 'us', 'general', 'china', 'invading', 'taiwan', 'a', "'mistake'", 'like', 'russia', 'in', 'ukraine']
# original someone drop that izcord link L ['someone', 'drop', 'that', 'izcord', 'link']
# original jin is the magnet we been knew,,,, our 1 million seller  L ['jin', 'is', 'the', 'magnet', 'we', 'been', 'knew', 'our', '1', 'million', 'seller']
# original uwah!! thank you so much  L ['uwah', 'thank', 'you', 'so', 'much']
# original top streamings a las 02:55 (hora esp) 24.789 19.720 16.3604) carpinchoolfateable14viewers: 8.5085) elzeeinviewers: 6.241 L ['top', 'streamings', 'a', 'las', '02', '55', '(hora', 'esp)', '24', '789', '19', '720', '16', '3604)', 'carpinchoolfateable14viewers', '8', '5085)', 'elzeeinviewers', '6', '241']
# original so glad your better  L ['so', 'glad', 'your', 'better']
# original check out this item on opensea via  available now!! L ['check', 'out', 'this', 'item', 'on', 'opensea', 'via', 'available', 'now']
# original fine! i'll keep it to myself then.  L ['fine', "i'll", 'keep', 'it', 'to', 'myself', 'then']
# original 19:24:17在线light tomorrow with today. L ['19', '24', '17在线light', 'tomorrow', 'with', 'today']
# original imagine having a iq low enough to encourage watch and indeed book intergender matches . respect to scott  L ['imagine', 'having', 'a', 'iq', 'low', 'enough', 'to', 'encourage', 'watch', 'and', 'indeed', 'book', 'intergender', 'matches', 'respect', 'to', 'scott']
# original about to do it again  L ['about', 'to', 'do', 'it', 'again']
# original breaking: bjp voters have decided to leave the planet after shah served them this piece of truth. sab jagah khushi ki lehar L ['breaking', 'bjp', 'voters', 'have', 'decided', 'to', 'leave', 'the', 'planet', 'after', 'shah', 'served', 'them', 'this', 'piece', 'of', 'truth', 'sab', 'jagah', 'khushi', 'ki', 'lehar']
# original the king james soda  L ['the', 'king', 'james', 'soda']
# original u are using airtel, 3k for 20gb  L ['u', 'are', 'using', 'airtel', '3k', 'for', '20gb']
# original hi everyone  in light of what's going on right now, we have created a tumblr, just in case. it will be updated within the week to have more content! thank you all for your support. we will continue to post here as usual as well! L ['hi', 'everyone', 'in', 'light', 'of', "what's", 'going', 'on', 'right', 'now', 'we', 'have', 'created', 'a', 'tumblr', 'just', 'in', 'case', 'it', 'will', 'be', 'updated', 'within', 'the', 'week', 'to', 'have', 'more', 'content', 'thank', 'you', 'all', 'for', 'your', 'support', 'we', 'will', 'continue', 'to', 'post', 'here', 'as', 'usual', 'as', 'well']
# original why does spaces never work for me  L ['why', 'does', 'spaces', 'never', 'work', 'for', 'me']
# original what happened with twitter why the trending all about twitter closing and rip. the trending really scared me at first twitter was my place to get my mood booster and spirit back whenever i'm in bad condition &amp; stress &amp; sad should i start to share my ig account  L ['what', 'happened', 'with', 'twitter', 'why', 'the', 'trending', 'all', 'about', 'twitter', 'closing', 'and', 'rip', 'the', 'trending', 'really', 'scared', 'me', 'at', 'first', 'twitter', 'was', 'my', 'place', 'to', 'get', 'my', 'mood', 'booster', 'and', 'spirit', 'back', 'whenever', "i'm", 'in', 'bad', 'condition', 'amp;', 'stress', 'amp;', 'sad', 'should', 'i', 'start', 'to', 'share', 'my', 'ig', 'account']
# original the stature he earned for himself is incredible. hero.  L ['the', 'stature', 'he', 'earned', 'for', 'himself', 'is', 'incredible', 'hero']
# original happy 2 org a  sweeping session if we have some volunteers - we  the  in leaf    cages as leaf mould would be impressed with the results for our plants . . dm us if interested . it’s a great workout  &amp;  L ['happy', '2', 'org', 'a', 'sweeping', 'session', 'if', 'we', 'have', 'some', 'volunteers', '-', 'we', 'the', 'in', 'leaf', 'cages', 'as', 'leaf', 'mould', 'would', 'be', 'impressed', 'with', 'the', 'results', 'for', 'our', 'plants', 'dm', 'us', 'if', 'interested', 'it’s', 'a', 'great', 'workout', 'amp;']
# original bandee update! hugging kirby  L ['bandee', 'update', 'hugging', 'kirby']
# original uh. thus on the weekend twitter is may go dark?  L ['uh', 'thus', 'on', 'the', 'weekend', 'twitter', 'is', 'may', 'go', 'dark']
# original farewell my sun, till we meet again  L ['farewell', 'my', 'sun', 'till', 'we', 'meet', 'again']
# original  her glittering eyes would sparkle with shock and wonder as she watches his ( 𝑷𝑯𝑬𝑵𝑶𝑴𝑬𝑵𝑨𝑳 𝑻𝑹𝑵𝑨𝑺𝑭𝑶𝑹𝑴𝑨𝑻𝑰𝑶𝑵 )** happens right before her . his blinding golden shimmering aura engulfs the ( 𝑷𝑶𝑻𝑨𝑹𝑨 𝑭𝑼𝑺𝑰𝑶𝑵 )**'s body (  ) L ['her', 'glittering', 'eyes', 'would', 'sparkle', 'with', 'shock', 'and', 'wonder', 'as', 'she', 'watches', 'his', '(', '𝑷𝑯𝑬𝑵𝑶𝑴𝑬𝑵𝑨𝑳', '𝑻𝑹𝑵𝑨𝑺𝑭𝑶𝑹𝑴𝑨𝑻𝑰𝑶𝑵', ')', 'happens', 'right', 'before', 'her', 'his', 'blinding', 'golden', 'shimmering', 'aura', 'engulfs', 'the', '(', '𝑷𝑶𝑻𝑨𝑹𝑨', '𝑭𝑼𝑺𝑰𝑶𝑵', ')', "'s", 'body', '(', ')']
# original all the best for your first ever world tour!  L ['all', 'the', 'best', 'for', 'your', 'first', 'ever', 'world', 'tour']
# original just like your daddy elon musk  L ['just', 'like', 'your', 'daddy', 'elon', 'musk']
# original please, like mr. kurzin, conduct a survey on the type of future government of iran( constitutional monarchy, republic) . L ['please', 'like', 'mr', 'kurzin', 'conduct', 'a', 'survey', 'on', 'the', 'type', 'of', 'future', 'government', 'of', 'iran(', 'constitutional', 'monarchy', 'republic)']
# original gm gm! friday 11:55amenjoy your friday  L ['gm', 'gm', 'friday', '11', '55amenjoy', 'your', 'friday']
# original you copycat!i’ve bean on instajam for ages at mr._t_the_taco  L ['you', 'copycat', 'i’ve', 'bean', 'on', 'instajam', 'for', 'ages', 'at', 'mr', '_t_the_taco']
# original pls i want em both but it seems like i only can choose one L ['pls', 'i', 'want', 'em', 'both', 'but', 'it', 'seems', 'like', 'i', 'only', 'can', 'choose', 'one']
# original  world of warcraft - top streams a las 05:46 (hora esp) 4.223 779 4284) raevenccaviewers: 3745) irvingafviewers: 3146) peperonishviewers: 229 L ['world', 'of', 'warcraft', '-', 'top', 'streams', 'a', 'las', '05', '46', '(hora', 'esp)', '4', '223', '779', '4284)', 'raevenccaviewers', '3745)', 'irvingafviewers', '3146)', 'peperonishviewers', '229']
# original finally get to have a day to pamper myself today. i’m excited! it’s well needed and deserved. L ['finally', 'get', 'to', 'have', 'a', 'day', 'to', 'pamper', 'myself', 'today', 'i’m', 'excited', 'it’s', 'well', 'needed', 'and', 'deserved']
# original robotics....but only natural  romantics only.we know you know 3rd dimensional intelligent enlightened humans know we have better livlihoods then planet earth.better habitable climatic atmospheric conditions then our planet earth. in trill L ['robotics', 'but', 'only', 'natural', 'romantics', 'only', 'we', 'know', 'you', 'know', '3rd', 'dimensional', 'intelligent', 'enlightened', 'humans', 'know', 'we', 'have', 'better', 'livlihoods', 'then', 'planet', 'earth', 'better', 'habitable', 'climatic', 'atmospheric', 'conditions', 'then', 'our', 'planet', 'earth', 'in', 'trill']
# original covid surging in australia. what's our elected governments doing? (nothing) L ['covid', 'surging', 'in', 'australia', "what's", 'our', 'elected', 'governments', 'doing', '(nothing)']
# original woohoo  and happy thanksgiving to south carolinians   L ['woohoo', 'and', 'happy', 'thanksgiving', 'to', 'south', 'carolinians']
# original  iranian courts are now issuing death sentences to those who take part in the nationwide protests. this week, five people have been sentenced to execution for participating in the protests. | | L ['iranian', 'courts', 'are', 'now', 'issuing', 'death', 'sentences', 'to', 'those', 'who', 'take', 'part', 'in', 'the', 'nationwide', 'protests', 'this', 'week', 'five', 'people', 'have', 'been', 'sentenced', 'to', 'execution', 'for', 'participating', 'in', 'the', 'protests']
# original happy to know na finally naka uwi na sayoo. thank you as well for the patience  till next time ~ L ['happy', 'to', 'know', 'na', 'finally', 'naka', 'uwi', 'na', 'sayoo', 'thank', 'you', 'as', 'well', 'for', 'the', 'patience', 'till', 'next', 'time', '~']
# original omg that’s a prolific list, victor , when i was a small child i cosplayed ginko from mushishi, had the medicine seller box and everything. i love drawing! i do mix of abstract and realism! L ['omg', 'that’s', 'a', 'prolific', 'list', 'victor', 'when', 'i', 'was', 'a', 'small', 'child', 'i', 'cosplayed', 'ginko', 'from', 'mushishi', 'had', 'the', 'medicine', 'seller', 'box', 'and', 'everything', 'i', 'love', 'drawing', 'i', 'do', 'mix', 'of', 'abstract', 'and', 'realism']
# original waste of oxygen scum L ['waste', 'of', 'oxygen', 'scum']
# original my fave magpasikat performance this year! gaandaaaa  L ['my', 'fave', 'magpasikat', 'performance', 'this', 'year', 'gaandaaaa']
# original today at 11am utc, i'll be attending the loozr incentivized testnet: bolt v1.0 event. join by clicking here:  L ['today', 'at', '11am', 'utc', "i'll", 'be', 'attending', 'the', 'loozr', 'incentivized', 'testnet', 'bolt', 'v1', '0', 'event', 'join', 'by', 'clicking', 'here']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-76-9451b0e36a2e> in <module>
# ----> 1 train_dataset=TextDataset(glove,train)
#       2  #each dataloader is a batch
#       3 train_dataloader = torch.utils.data.DataLoader(
#       4         dataset=train_dataset,
#       5         batch_size=3,
#
# <ipython-input-75-f3fdf64ba698> in __init__(self, vocab, df)
#      21             temp=row["emojis_num"]
#      22             temp=torch.tensor(temp)
# ---> 23             temp=F.one_hot(temp,num_classes=60)
#      24             # print("Y",temp)
#      25             Y.append(temp)
#
# KeyboardInterrupt:

# %%
train['tweets'][5]

# %%
train_dataset[5]

# %%
train_iter=iter(train_dataloader)
count=0
for a,b in train_dataloader:
  print(a.shape)
  count=count+1
  print(b.shape)
  if count==2:
    break

# %%
# my_collate_function prepares batches
# it also pads each batch with zeroes.
def my_collate_function(batch, device):
    # Handle the padding here
    # batch is approximately: [dataset[i] for i in range(0, batch_size)]
    # Since the dataset[i]'s contents is defined in the __getitem__() above, this collate function 
    # should be set correspondingly.
    # Also: collate_function just takes one argument. To pass in additional arguments (e.g., device), 
    # we need to wrap up an anonymous function (using lambda below)
    batch_x, batch_y = [], []
    max_len = 0
    for x,y in batch:
        # print('X',x,"Y",y)
        batch_y.append(y)
        max_len = max(max_len, len(x))#longest sentence in a batch
    for x,y in batch:
      #if sentence not longest, set rest token as 0
        x_p = torch.concat(
            [x, torch.zeros(max_len - len(x))]
        )
        batch_x.append(x_p)
    # print("batchy",batch_y)
    X=torch.stack(batch_x).t().int().to(device)
    # print("a",a)
    Y=torch.stack(batch_y).t().int().to(device)
    # print("b",b)
    return X,Y

# %%
class Baseline(nn.Module):#Baseline model

    def __init__(self, embedding_dim, vocab):
        super(Baseline, self).__init__()
        #100 vectors for each word 
        #embedding.shape=[embedding dim,glove.len]
        self.embedding = nn.Embedding.from_pretrained(vocab.vectors)
        self.fc = nn.Linear(embedding_dim, 60)

    def forward(self, x, len=None):
        #x has shape [sentence length, batch size]
        embedded = self.embedding(x)#embedded.shape=[sentence len, batch size,embedding size]
        # print("embedded",embedded.shape)
        average = embedded.mean(0) # average.shape=[batch size, embedding size]
        # print("average",average.shape)
        prediction = self.fc(average)
        # print("prediction",prediction.shape)
        # prediction=torch.nn.Softmax()(prediction)
        prediction=F.log_softmax(prediction,dim=1)
        # print("lof sofamax",prediction.shape)
        return prediction

# %%
def evaluate(model,dataloader,criterion):
    total_corr=0
    iterator=iter(dataloader)
    temp_loss=0
    for n, (input,labels) in enumerate(iterator):
      labels=labels.reshape(-1,60)
      # print("labels",labels.shape)
      prediction=model(input,input.size(dim=0))
      # print("predict",prediction.shape)
      loss=criterion(input=prediction.float(),target=labels.float())
      #Count correct examples
      
      pre=torch.argmax(prediction,dim=1)
      true=torch.argmax(labels,dim=1)
      corr=torch.count_nonzero(torch.eq(true,pre))
 
      total_corr=total_corr+int(corr.sum())
      temp_loss=loss+temp_loss 
    accuracy=float(total_corr)/len(dataloader.dataset)
    loss=(temp_loss/len(iterator))
    #print("validation accuracy",accuracy)
    return accuracy,loss

# %%
#Baseline code start
def main(args):
    #   fix seed
    torch.manual_seed(2)

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print ("Using device:", device)

    ### 3.3 Processing of the data ###
    # 3.3.1
    # The first time you run this will download a 862MB size file to .vector_cache/glove.6B.zip
    # glove = torchtext.vocab.GloVe(name="6B",dim=100) # embedding size = 100
    glove=torchtext.vocab.GloVe(name='840B',dim=300)
                                   
    # 3.3.2

    train_dataset=TextDataset(glove,train)
    val_dataset = TextDataset(glove,valid)
    test_dataset = TextDataset(glove, test)
        
    # 3.3.3
    #each dataloader is a batch
    train_dataloader = torch.utils.data.DataLoader(
        dataset=train_dataset, 
        batch_size=args.batch_size, 
        shuffle=False, 
        collate_fn=lambda batch: my_collate_function(batch, device))

    validation_dataloader = torch.utils.data.DataLoader(
        dataset=val_dataset, 
        batch_size=args.batch_size, 
        shuffle=False, 
        collate_fn=lambda batch: my_collate_function(batch, device))
   # print(args)
    test_dataloader = torch.utils.data.DataLoader(
        dataset=test_dataset,
        batch_size=args.batch_size,
        shuffle=False,
        collate_fn=lambda batch: my_collate_function(batch, device))

    #Constants
    embedding_size=300
    epochs=
    lr=0.001
    criterion=torch.nn.CrossEntropyLoss()  

    #training
    model=Baseline(embedding_size,glove).to(device)
    optimizer=torch.optim.Adam(model.parameters(), lr)
    epoch_list=[]
    train_loss=[]
    accuracy_train=[]
    accuracy_valid=[]
    accuracy_test=[]
    valid_loss=[]
    test_loss=[]

    for epoch in range(epochs):
        print("epoch",epoch)
        train_iter=iter(train_dataloader)
        valid_iter=iter(validation_dataloader)
        test_iter=iter(test_dataloader)
     
       
        # a,b,c=model.parameters()
        # print(b)
        # print("-----------------------------------------------------------------------------------------------")
        epoch_list.append(epoch+1)
        

        ##TRAINING SET
        for n, (input,labels) in enumerate(train_iter):
            # print("current epoch",epoch)
            labels=labels.reshape(-1,60)
            # print("n",n)
            # print("labels",labels.shape)
            prediction=model(input,input.size(dim=0))
            # print("prediciton",prediction.shape)
            # print("prediction",prediction)
            # print("true labels",labels)
            optimizer.zero_grad()
            loss=criterion(input=prediction.float(),target=labels.float())
            # print("------------------------------------------")
            # print("loss",loss)
            #backward pass and update gradient
            loss.backward()
            optimizer.step()
            # #Count correct examples
            # pre=torch.argmax(prediction,dim=1)
            # true=torch.argmax(labels,dim=1)
            # corr=torch.count_nonzero(torch.eq(true,pre))
            # print("pre",pre)
            # print("true",true)
            # print("correct number",corr)

            # corr = ((prediction > 0.5).squeeze().long() == labels.long())
            # total_corr_train=total_corr_train+int(corr.sum())
            # temp_loss=loss+temp_loss
                 
        # # accuracy=float(total_corr_train)/len(train_dataset)
        accuracy,t_loss=evaluate(model,train_dataloader,criterion)
        print("loss",loss)
        print("accuracy",accuracy)
        train_loss.append(t_loss)
        accuracy_train.append(accuracy)
        if (epoch + 1) % 10 == 0:
          print("-----------------------------------------------------------------------------------------------")
          print('Epoch:', '%03d' % (epoch + 1), 'accuracy =', accuracy_train)

     

        # #validation #for 4.4
        # # print("before go to valid",temp_loss)
        # for n, (input,labels) in enumerate(valid_iter):
        #     # print("current epoch",epoch)
        #     prediction=model(input,input.size(dim=0)) 
        #     loss=criterion(input=prediction.float().squeeze(),target=labels.float().squeeze())
            
        #     
        #     # # #Count correct examples
        #     # corr = ((prediction > 0.5).squeeze().long() == labels.long())
        #     # total_corr_valid=total_corr_valid+int(corr.sum())
           
        #     temp_loss=loss+temp_loss  
        #     # print("temp loss",temp_loss)  
        # #print("validation length",len(val_dataset)) 
        # # accuracy=float(total_corr_valid)/len(val_dataset)
        # valid_loss.append(temp_loss/len(valid_iter))
        
        ###4.5 Validation loss, accuracy
        accuracy,v_loss=evaluate(model,validation_dataloader,criterion)
        valid_loss.append(v_loss)
        accuracy_valid.append(accuracy)
        #Test Loss, accuracy
       
        t_acc,t_loss=evaluate(model,test_dataloader,criterion)
        test_loss.append(t_loss)
        accuracy_test.append(t_acc)
    
    ####4.6

    # a,b,c=model.parameters()
    torch.save(model.state_dict(),'model_baseline.pt')
        
    print("epoch list",epoch_list)

  #  ##Train dataset
    train_loss=torch.stack(train_loss)
    train_loss=train_loss.detach().cpu().clone().numpy()   
    print("train loss",train_loss)
    print("train accuracy list",accuracy_train)
    ##Validation dataset
    valid_loss=torch.stack(valid_loss)
    valid_loss=valid_loss.detach().cpu().clone().numpy() 
    print("valid accuracy list",accuracy_valid)
    print("valid loss",valid_loss)
    ##Test dataset
    test_loss=torch.stack(test_loss)
    test_loss=test_loss.detach().cpu().clone().numpy() 
    print("test accuracy list",accuracy_test)
    print("test loss",test_loss)


    plt.plot(epoch_list,train_loss,color='magenta',label="training error")
    plt.plot(epoch_list,valid_loss,color='blue',label="validation error")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title("Loss vs. Epoch")
    plt.legend(loc="upper right")
    plt.show()

    plt.plot(epoch_list,accuracy_train,color='magenta',label="training accuracy")
    plt.plot(epoch_list,accuracy_valid,color='blue',label="validation accuracy")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.title("Accuracy vs. Epoch")
    plt.legend(loc="upper right")
    plt.show()
    
    ##Plot test accuracy
    plt.plot(epoch_list,accuracy_test,color='magenta',label="test accuracy")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.title("Accuracy vs. Epoch")
    plt.legend(loc="upper right")
    plt.show()

    ##plot test loss
    plt.plot(epoch_list,test_loss,color='magenta',label="test loss")
    plt.xlabel("Epoch")
    plt.ylabel("Error")
    plt.title("Error vs. Epoch")
    plt.legend(loc="upper right")
    plt.show()
  #   for param_tensor in model.state_dict():
  #     print(param_tensor, "\t", model.state_dict()[param_tensor].size())
    



    # Instantiate your model(s) and train them and so on 
    # We suggest parameterizing the model - k1, n1, k2, n2, and other hyperparameters
    # so that it is easier to experiment with
  

if __name__ == '__main__':
  parser = argparse.ArgumentParser()
  parser.add_argument('-f')
  parser.add_argument('--batch-size', type=int, default=10)
  args=parser.parse_args()
  main(args)
# Out:
# Using device: cuda
# epoch 0
# loss tensor(4.0336, device='cuda:0', grad_fn=<DivBackward1>)
# accuracy 0.015520833333333333
# epoch 1
# loss tensor(4.0211, device='cuda:0', grad_fn=<DivBackward1>)
# accuracy 0.016744791666666668
# epoch 2
# loss tensor(4.0116, device='cuda:0', grad_fn=<DivBackward1>)
# accuracy 0.01734375
# epoch 3
# loss tensor(4.0038, device='cuda:0', grad_fn=<DivBackward1>)
# accuracy 0.017916666666666668
# epoch 4
# loss tensor(3.9970, device='cuda:0', grad_fn=<DivBackward1>)
# accuracy 0.018424479166666667
# epoch 5
# loss tensor(3.9910, device='cuda:0', grad_fn=<DivBackward1>)
# accuracy 0.0187890625
# epoch 6
# loss tensor(3.9856, device='cuda:0', grad_fn=<DivBackward1>)
# accuracy 0.019283854166666666
# epoch 7
# loss tensor(3.9806, device='cuda:0', grad_fn=<DivBackward1>)
# accuracy 0.019505208333333333
# epoch 8
# loss tensor(3.9761, device='cuda:0', grad_fn=<DivBackward1>)
# accuracy 0.019921875
# epoch 9
# loss tensor(3.9718, device='cuda:0', grad_fn=<DivBackward1>)
# accuracy 0.02020833333333333
# -----------------------------------------------------------------------------------------------
# Epoch: 010 accuracy = [0.015520833333333333, 0.016744791666666668, 0.01734375, 0.017916666666666668, 0.018424479166666667, 0.0187890625, 0.019283854166666666, 0.019505208333333333, 0.019921875, 0.02020833333333333]
# epoch 10
# loss tensor(3.9678, device='cuda:0', grad_fn=<DivBackward1>)
# accuracy 0.020520833333333332
# epoch 11
# loss tensor(3.9640, device='cuda:0', grad_fn=<DivBackward1>)
# accuracy 0.020677083333333332
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-81-a3e19bea57b2> in <module>
#     209   parser.add_argument('--batch-size', type=int, default=10)
#     210   args=parser.parse_args()
# --> 211   main(args)
#
# <ipython-input-81-a3e19bea57b2> in main(args)
#     129
#     130         ###4.5 Validation loss, accuracy
# --> 131         accuracy,v_loss=evaluate(model,validation_dataloader,criterion)
#     132         valid_loss.append(v_loss)
#     133         accuracy_valid.append(accuracy)
#
# <ipython-input-80-abedce5170e3> in evaluate(model, dataloader, criterion)
#      15       corr=torch.count_nonzero(torch.eq(true,pre))
#      16
# ---> 17       total_corr=total_corr+int(corr.sum())
#      18       temp_loss=loss+temp_loss
#      19     accuracy=float(total_corr)/len(dataloader.dataset)
#
# KeyboardInterrupt:
